# %% [markdown]
# A RegEx, or Regular Expression, is a sequence of characters that forms a search pattern.
#
# RegEx can be used to check if a string contains the specified search pattern.

# %%
# re.search
import re

txt = 'The rain in Spain'
x = re.search('^The.*Spain$' , txt)
print(x)
# Out:
# <re.Match object; span=(0, 17), match='The rain in Spain'>

# %%
# re.findall

txt = 'The rain in Spain'
x=re.findall('ai',txt)
print(x)
# Out:
# ['ai', 'ai']

# %%
txt = 'The rain in Spain'
x=re.findall('Portugal',txt)
print(x)
# Out:
# []

# %%
txt = 'The rain in Spain'
x = re.search('\s',txt)
print('the fist white-space character is located in position:',x.start())
# Out:
# the fist white-space character is located in position: 3

# %%
txt = 'TheraininSpain'
x = re.search('\s',txt)
print('the fist white-space character is located in position:',x)
# Out:
# the fist white-space character is located in position: None

# %%
# re.split()

text = 'The rain in Spain'
x=re.split('\s',text)
print(x)
# Out:
# ['The', 'rain', 'in', 'Spain']

# %%
text = 'The rain in Spain'
x=re.split('\s',text,1)
print(x)
# Out:
# ['The', 'rain in Spain']

# %%
# re.sub()

txt = 'The rain in Spain'
x=re.sub('\s','9',txt)
print(x)
# Out:
# The9rain9in9Spain

# %%
txt = 'The rain in Spain'
x = re.search('ai', txt)
print(x)
# Out:
# <re.Match object; span=(5, 7), match='ai'>

# %% [markdown]
# # Match Object
# A Match Object is an object containing information about the search and the result.

# %% [markdown]
# The Match object has properties and methods used to retrieve information about the search, and the result:
#
# .span() returns a tuple containing the start-, and end positions of the match.
# .string returns the string passed into the function
# .group() returns the part of the string where there was a match

# %%
txt = 'The rain in Spain'
x=re.search(r'\bS\w+',txt)
print(x.span())
# Out:
# (12, 17)

# %%
txt = 'The rain in Spain'
x=re.search(r'\bS\w+',txt)
print(x.string)
# Out:
# The rain in Spain

# %%
txt = "The rain in Spain"
x = re.search(r"\bS\w+", txt)
print(x.group())
# Out:
# Spain
